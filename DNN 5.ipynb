# %%
# ANN
# CNN
# Pad , Stride ,CNN

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
from tensorflow.keras import Sequential
from keras import layers

# %%
(X_train,y_train),(X_test,y_test)=keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
ann =Sequential([
        layers.Flatten(input_shape=(32,32,3)),
        layers.Dense(3000, activation='relu'),
        layers.Dense(1000, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])

ann.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

ann.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 12s 6ms/step - loss: 1.8126 - accuracy: 0.3558
# Epoch 2/5
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.6264 - accuracy: 0.4271
# Epoch 3/5
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5428 - accuracy: 0.4577
# Epoch 4/5
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4835 - accuracy: 0.4764
# Epoch 5/5
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4323 - accuracy: 0.4946

# %%
cnn =Sequential([
        layers.Conv2D(filters=32,kernel_size=(3,3),activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D(pool_size=(2,2)),

        layers.Conv2D(filters=64,kernel_size=(3,3),activation='relu'),
        layers.MaxPool2D(pool_size=(2,2)),

        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])

cnn.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

cnn.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 10s 5ms/step - loss: 2.0037 - accuracy: 0.2726
# Epoch 2/5
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6388 - accuracy: 0.4144
# Epoch 3/5
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4346 - accuracy: 0.4886
# Epoch 4/5
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3190 - accuracy: 0.5339
# Epoch 5/5
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.2330 - accuracy: 0.5653

# %%
cnn_1=Sequential([
        layers.Conv2D(filters=32,kernel_size=(3,3),activation='relu',input_shape=(32,32,3),strides=(2,2),padding='valid'),
        layers.MaxPool2D(pool_size=(2,2)),

        layers.Conv2D(filters=64,kernel_size=(3,3),activation='relu'),
        layers.MaxPool2D(pool_size=(2,2)),

        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])

cnn_1.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

cnn_1.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 8s 4ms/step - loss: 2.1474 - accuracy: 0.2046
# Epoch 2/5
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.8913 - accuracy: 0.3115
# Epoch 3/5
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7185 - accuracy: 0.3795
# Epoch 4/5
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6191 - accuracy: 0.4164
# Epoch 5/5
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5529 - accuracy: 0.4430
